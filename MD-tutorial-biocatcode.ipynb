# %% [markdown]
# ![image.png](attachment:0299a923-f638-4a91-af8e-1ac66a842076.png)![image.png](attachment:78b8468b-4652-410d-8313-349e083fb799.png)![image.png](attachment:0726e7fc-3fa1-4c44-a9ea-5dc5d216bbe6.png)![image.png](attachment:a36ce799-22f9-4760-9666-c1b486b32a94.png)Introduction to Molecular Dynamics Simulations with AMBER
#
# Author: Bruno Di Geronimo
# Contact: bgeronimo3@gatech.edu
# Github: https://github.com/BruDiGe/biocatcodeexpander-2024.git

# %% [raw]
# #Introduction to Molecular Dynamics Simulations with AMBER
#
# Author: Bruno Di Geronimo
# Contact: bgeronimo3@gatech.edu
# Github: https://github.com/BruDiGe/biocatcodeexpander-2024.git
#
# Useful links:
# https://ambermd.org/index.php

# %%
print(2+2)
# Out:
# 4

# %%
conda install -c conda-forge ambertools=23
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - ambertools=23
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ambertools-23.6            |nompi_py311h0f030ec_103        84.3 MB  conda-forge
#     arpack-3.9.1               |nompi_hf81eadf_101         123 KB  conda-forge
#     blosc-1.21.5               |       hafa3907_1          46 KB  conda-forge
#     boost-cpp-1.84.0           |       h07eb623_3          16 KB  conda-forge
#     ca-certificates-2024.8.30  |       h8857fd0_0         155 KB  conda-forge
#     cached-property-1.5.2      |       hd8ed1ab_1           4 KB  conda-forge
#     cached_property-1.5.2      |     pyha770c72_1          11 KB  conda-forge
# ...

# %% [markdown]
# tleap

# %%
cpptraj
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 cpptraj
#
# NameError: name 'cpptraj' is not defined

# %%
tleap
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 tleap
#
# NameError: name 'tleap' is not defined

# %%
tleap
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 tleap
#
# NameError: name 'tleap' is not defined
