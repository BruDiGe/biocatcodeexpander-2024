# %% [markdown]
# <a href="https://colab.research.google.com/github/BruDiGe/biocatcodeexpander-2024/blob/main/test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q condacolab

# %%
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:15
# 🔁 Restarting kernel...

# %%
# !conda --version
# Out:
# conda 23.11.0

# %%
# !conda create --name AmberTools23
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/AmberTools23
#
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate AmberTools23
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# !conda init zsh
# Out:
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.10/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# modified      /root/.zshrc
#
# ==> For changes to take effect, close and re-open your current shell. <==

# %%
# !source activate base

# %%
# !source activate AmberTools23

# %%
ls /usr/local/envs/AmberTools23/conda-meta/
# Out:
# history

# %%
# !conda install -c conda-forge ambertools=23
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - ambertools=23
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ambertools-23.6            |nompi_py310hcbc9ba0_103        90.2 MB  conda-forge
#     arpack-3.9.1               |nompi_h77f6705_101         127 KB  conda-forge
#     blosc-1.21.5               |       hc2324a3_1          48 KB  conda-forge
#     brotli-1.1.0               |       hd590300_1          19 KB  conda-forge
#     brotli-bin-1.1.0           |       hd590300_1          19 KB  conda-forge
# ...

# %%
ls /usr/local/AmberTools/src/cpptraj/dat/
# Out:
# ATOMTYPE_CHECK.TAB                 CMakeLists.txt   PDB_ResidueNames.txt
# BONDTYPE_CHECK.TAB                 GlycamCodes.csv  README
# Carbohydrate_PDB_Glycam_Names.txt  Karplus.txt      ResNames.sugar.dat

# %%
# !source activate AmberTools23

# %%
# !which cpptraj
# Out:
# /usr/local/bin/cpptraj

# %%
ls /usr/local/bin/
# Out:
# 2to3@                                   metalpdb2mol2.py*
# 2to3-3.10*                              metatwist*
# accelerate*                             mm_pbsa_nabnmode*
# accelerate-config*                      mm_pbsa.pl*
# accelerate-estimate-memory*             MMPBSA.py*
# accelerate-launch*                      mmpbsa_py_energy*
# accelerate-merge-weights*               MMPBSA.py.MPI*
# activate*                               mmpbsa_py_nabnmode*
# addles*                                 mm_pbsa_statistics.pl*
# add_pdb*                                mol2rtf.py*
# AddToBox*                               natsort*
# add_xray*                               nc-config*
# adig*                                   nccopy*
# ahost*                                  ncdump*
# am1bcc*                                 ncgen*
# amb2chm_par.py*                         ncgen3*
# amb2chm_psf_crd.py*                     ncurses6-config*
# amb2gro_top_gro.py*                     ncursesw6-config*
# ...
